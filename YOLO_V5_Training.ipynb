# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from zipfile import ZipFile
import os, sys, random
import shutil
from glob import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pwd
# Out:
# '/content'

# %%
os.chdir("/content/drive/MyDrive/YOLO_V5")
Curr_Directory = "/content/drive/MyDrive/YOLO_V5/Data/images"

path = "/content/drive/MyDrive/YOLO_V5/Data/images.zip"

# %%
# I am commenting this as i have already unzipped this

with ZipFile(path,'r') as data:
  #data.printdir()
  data.extractall(path=Curr_Directory) #Extracts all the files in zipfile to the current working directory

# %%
# !git clone  'https://github.com/ultralytics/yolov5.git'
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 5269 (delta 22), reused 23 (delta 8), pack-reused 5226
# Receiving objects: 100% (5269/5269), 8.01 MiB | 9.18 MiB/s, done.
# Resolving deltas: 100% (3595/3595), done.

# %%
# !pip install -qr '/content/drive/MyDrive/YOLO_V5/yolov5/requirements.txt'  # install dependencies
# Out:
#      |████████████████████████████████| 645kB 6.2MB/s

# %%
# We have to create a .yaml file with the path of the images and number of classes and class names

# %%
# !echo -e 'train: /content/drive/MyDrive/YOLO_V5/Data/images/train\nval: /content/drive/MyDrive/YOLO_V5/Data/images/valid\n\nnc: 2\nnames: ['Normal', 'Pneumonia']' >> /content/drive/MyDrive/YOLO_V5/pneumonia_det.yaml
# !cat '/content/drive/MyDrive/YOLO_V5/pneumonia_det.yaml'
# Out:
# train: /content/drive/MyDrive/YOLO_V5/Data/images/train
# val: /content/drive/MyDrive/YOLO_V5/Data/images/valid
#
# nc: 2
# names: [Normal, Pneumonia]

# %%
# We have to select the model we need and change the number of classes in the model

# I have selected the small version of the model, as the verison above this are not runnable in the free colab version due to memory issues

# %%
# !sed -i 's/nc: 80/nc: 2/g' /content/drive/MyDrive/YOLO_V5/yolov5/models/yolov5s.yaml

# %%
# %%time

# !python /content/drive/MyDrive/YOLO_V5/yolov5/train.py --img 1024 --batch 16 --epochs 300 --data /content/drive/MyDrive/YOLO_V5/pneumonia_det.yaml --cfg /content/drive/MyDrive/YOLO_V5/yolov5/models/yolov5s.yaml --name /content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial1
# Out:
# github: skipping check (not a git repository)
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='/content/drive/MyDrive/YOLO_V5/yolov5/models/yolov5s.yaml', data='/content/drive/MyDrive/YOLO_V5/pneumonia_det.yaml', device='', entity=None, epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='./drive/MyDrive/YOLO_V5/yolov5/data/hyp.scratch.yaml', image_weights=False, img_size=[1024, 1024], linear_lr=False, local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='/content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial1', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='/content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5s.pt', workers=8, world_size=1)
# ...

# %%
# we can resume our training any time by providing the last saved weights and --resume parameter to our train.py file

# %%time

# !python /content/drive/MyDrive/YOLO_V5/yolov5/train.py --img 1024 --batch 16 --epochs 8 --data /content/drive/MyDrive/YOLO_V5/pneumonia.yaml --weights /content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt --resume
# Out:
# github: skipping check (not a git repository)
# Resuming training from ./drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# %%time

# !python /content/drive/MyDrive/YOLO_V5/yolov5/train.py --img 1024 --batch 16 --epochs 10 --data /content/drive/MyDrive/YOLO_V5/pneumonia.yaml --weights /content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt --resume
# Out:
# github: skipping check (not a git repository)
# Resuming training from ./drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# %%time

# !python /content/drive/MyDrive/YOLO_V5/yolov5/train.py --img 1024 --batch 16 --epochs 20 --data /content/drive/MyDrive/YOLO_V5/pneumonia.yaml --weights /content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt --resume
# Out:
# github: skipping check (not a git repository)
# Resuming training from ./drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# %%time

# !python /content/drive/MyDrive/YOLO_V5/yolov5/train.py --img 1024 --batch 16 --epochs 90 --data /content/drive/MyDrive/YOLO_V5/pneumonia.yaml --weights /content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt --resume
# Out:
# github: skipping check (not a git repository)
# Resuming training from ./drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# ...

# %%
# %%time

# !python /content/drive/MyDrive/YOLO_V5/yolov5/train.py --img 1024 --batch 16 --epochs 120 --data /content/drive/MyDrive/YOLO_V5/pneumonia.yaml --weights /content/drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt --resume
# Out:
# github: skipping check (not a git repository)
# Resuming training from ./drive/MyDrive/YOLO_V5/runs/train/PneumoniaTrial12/weights/last.pt
# YOLOv5  torch 1.8.0+cu101 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# ...
